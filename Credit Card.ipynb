# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
train_df=pd.read_csv("F:/Paras/Simplilearn/Credit card/train.csv")
test_df=pd.read_csv("F:/Paras/Simplilearn/Credit card/test.csv")

# %%
train_df.head(10)
# Out:
#       ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  25150     360000    2          2         2   25     -1     -1     -1
# 1  13470     240000    2          1         2   46      2      2     -2
# 2   3092     320000    2          2         1   41      0      0      0
# 3  13973      50000    2          2         2   24     -1     -1     -2
# 4  10567      80000    1          3         1   52     -1      0      0
# 5  28050     150000    2          1         2   29     -2     -2     -2
# 6  23327     260000    2          1         1   36      0      0      0
# 7  10728      50000    2          2         1   31      0      0      0
# 8  17227     130000    2          2         2   24      0      0      0
# 9  22039      60000    2          3         2   28     -1     -1      0
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...       3435       8870       2020     12590      3479      3446
# ...

# %%
train_df.describe()
# Out:
#                  ID      LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  21000.000000   21000.000000  21000.000000  21000.000000  21000.000000
# mean   14949.183667  167214.746667      1.607571      1.854190      1.551714
# std     8632.775153  128965.188482      0.488303      0.791628      0.521176
# min        1.000000   10000.000000      1.000000      0.000000      0.000000
# 25%     7508.750000   50000.000000      1.000000      1.000000      1.000000
# 50%    14939.500000  140000.000000      2.000000      2.000000      2.000000
# 75%    22386.750000  240000.000000      2.000000      2.000000      2.000000
# max    29998.000000  800000.000000      2.000000      6.000000      3.000000
#
#                 AGE        PAY_0         PAY_2         PAY_3        PAY_4  \
# count  21000.000000  21000.00000  21000.000000  21000.000000  21000.00000
# mean      35.461619     -0.01119     -0.127238     -0.164857     -0.21819
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 25 columns):
# ID                            21000 non-null int64
# LIMIT_BAL                     21000 non-null int64
# SEX                           21000 non-null int64
# EDUCATION                     21000 non-null int64
# MARRIAGE                      21000 non-null int64
# AGE                           21000 non-null int64
# PAY_0                         21000 non-null int64
# PAY_2                         21000 non-null int64
# PAY_3                         21000 non-null int64
# PAY_4                         21000 non-null int64
# PAY_5                         21000 non-null int64
# PAY_6                         21000 non-null int64
# BILL_AMT1                     21000 non-null int64
# BILL_AMT2                     21000 non-null int64
# BILL_AMT3                     21000 non-null int64
# BILL_AMT4                     21000 non-null int64
# ...

# %% [markdown]
# # As per above there are no null values

# %% [markdown]
# * As per the data Education 5 and 6 it is mention as unkown so we replace as 4(others)

# %%
train_df.loc[train_df.EDUCATION>4,'EDUCATION']= 4
test_df.loc[test_df.EDUCATION>4,'EDUCATION'] = 4

# %%
train_df.head(15)
# Out:
#        ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0   25150     360000    2          2         2   25     -1     -1     -1
# 1   13470     240000    2          1         2   46      2      2     -2
# 2    3092     320000    2          2         1   41      0      0      0
# 3   13973      50000    2          2         2   24     -1     -1     -2
# 4   10567      80000    1          3         1   52     -1      0      0
# 5   28050     150000    2          1         2   29     -2     -2     -2
# 6   23327     260000    2          1         1   36      0      0      0
# 7   10728      50000    2          2         1   31      0      0      0
# 8   17227     130000    2          2         2   24      0      0      0
# 9   22039      60000    2          3         2   28     -1     -1      0
# 10    196      50000    2          1         2   24      1      2      2
# 11  29007     150000    2          1         2   34      1     -1     -1
# ...

# %%
fig=sns.countplot(x='default_payment_next_month',data=train_df)
fig.set_xticklables(['0', '1'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d2aa69bf5819> in <module>
#       1 fig=sns.countplot(x='default_payment_next_month',data=train_df)
# ----> 2 fig.set_xticklables(['0', '1'])
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xticklables'

# %% [markdown]
# * 0= Non Default, 1=Default

# %%
sns.countplot(x="MARRIAGE", data=train_df,hue="default_payment_next_month", palette="muted")

# %% [markdown]
# * from above we can see  that those people who have marital status single have less default payment wrt married status people.

# %%
sns.pairplot(train_df, hue = 'default_payment_next_month', vars = ['AGE', 'MARRIAGE', 'SEX', 'EDUCATION', 'LIMIT_BAL'] )

# %% [markdown]
# *Finding Correaltion

# %%
X = train_df.drop(['default_payment_next_month'],axis=1)
y = train_df['default_payment_next_month']

# %%
X.corrwith(train_df['default_payment_next_month']).plot.bar(
        figsize = (20, 10), title = "Correlation with Default", fontsize = 20,
        rot = 90, grid = True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(random_state = 47, 
                                    criterion = 'entropy',n_estimators=100)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=47, verbose=0,
#                        warm_start=False)

# %%
y_pred_r = classifier.predict(X_test)
from sklearn.metrics import  accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
roc=roc_auc_score(y_test, y_pred_r)
acc = accuracy_score(y_test, y_pred_r)
prec = precision_score(y_test, y_pred_r)
rec = recall_score(y_test, y_pred_r)
f1 = f1_score(y_test, y_pred_r)
results = pd.DataFrame([['Random_forest_ent100 ', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results
# Out:
#                    Model  Accuracy  Precision   Recall  F1 Score       ROC
# 0  Random_forest_ent100   0.815952   0.654649  0.36859  0.471634  0.656415

# %%
predictions = classifier.predict(test_df)

# %%
submission = pd.DataFrame({'ID':test_df['ID'],'default_payment_next_month':predictions})
submission.head(10)
# Out:
#       ID  default_payment_next_month
# 0  10178                           0
# 1   5304                           0
# 2   5187                           0
# 3  14495                           0
# 4  20444                           0
# 5  17667                           0
# 6  21211                           0
# 7   7178                           1
# 8  20783                           0
# 9  24033                           0

# %%
filename = 'RandomForest Classifier Pred.csv'

submission.to_csv(filename,index=False)

print('Saved file: ' + filename)
# Out:
# Saved file: RandomForest Classifier Pred.csv
